# %% [markdown]
# <a href="https://colab.research.google.com/github/gear66me-ui/JWST/blob/main/JWST_MASTER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -fsSL -o /content/JWST_0004_Z13_DISTANCE_EDGE_MAP.py https://raw.githubusercontent.com/gear66me-ui/JWST/main/JWST_0004_Z13_DISTANCE_EDGE_MAP.py
# %run /content/JWST_0004_Z13_DISTANCE_EDGE_MAP.py
# Out:
# CODE OUTPUT: JWST_0004
#
# CODE INPUTS
# Field           | Value
# --------------------------------------------------------
# Project         | JWST Z>=13 DISTANCE EDGE MAP
# Output folder   | /content/JWST_OUTPUT
# Objects         | 7
# Cutoff          | z >= 13
# Radial distance | Planck18 comoving distance, Gly
# Outer ring      | Observable radius marker 46.5 Gly
# Mode            | Curated metadata only; no FITS/image …
# RESULTS
# Rank | Name              | z       | Dist Gly | Edge gap | Age Myr
# ------------------------------------------------------------------
# 1    | MoM-z14           | 14.4400 | 33.861   | 12.639   | 283.1
# 2    | JADES-GS-z14-0    | 14.1793 | 33.748   | 12.752   | 290.4
# 3    | JADES-GS-z14-1    | 13.8600 | 33.606   | 12.894   | 299.9
# 4    | PAN-z14-1         | 13.5300 | 33.455   | 13.045   | 310.2
# 5    | JADES-GS-z13-0    | 13.2000 | 33.298   | 13.202   | 321.1
# 6    | UNCOVER-z13       | 13.0790 | 33.239   | 13.261   | 325.2
# ...

# %%
# !curl -fsSL -o /content/JWST_0005_OLDEST_GALAXIES_DISTANCE_LINEARITY.py https://raw.githubusercontent.com/gear66me-ui/JWST/main/JWST_0005_OLDEST_GALAXIES_DISTANCE_LINEARITY.py
# %run /content/JWST_0005_OLDEST_GALAXIES_DISTANCE_LINEARITY.py
# Out:
# CODE OUTPUT: JWST_0005
#
# CODE INPUTS
# Field          | Value
# -----------------------------------------------------
# Project        | OLDEST GALAXIES DISTANCE LINEARITY …
# Output folder  | /content/JWST_OUTPUT
# Named objects  | 31
# Distance model | Astropy Planck18 cosmology
# Question       | distance/redshift linearity
# Mode           | Curated metadata only; no FITS/imag…
# RESULTS
# Metric                  | Value
# -----------------------------------------------------------
# Linear fit slope        | 0.773897 Gly per redshift
# Linear fit intercept    | 23.229493 Gly
# Linear fit R2           | 0.97832513
# Linear fit RMS residual | 0.339120 Gly
# Interpretation          | monotonic but nonlinear at high z
#
# OLDEST OBJECTS
# Rank | Name              | z       | Dist Gly | Age Myr | Era
# ---------------------------------------------------------------------
# 1    | MoM-z14           | 14.4400 | 33.861   | 283.1   | JWST
# ...

# %%
# !curl -fsSL -o /content/JWST_0006_JWST_EDGE_BANDWIDTH_MAP.py https://raw.githubusercontent.com/gear66me-ui/JWST/main/JWST_0006_JWST_EDGE_BANDWIDTH_MAP.py
# %run /content/JWST_0006_JWST_EDGE_BANDWIDTH_MAP.py
# Out:
# CODE OUTPUT: JWST_0006
#
# CODE INPUTS
# Field          | Value
# -----------------------------------------------------------
# Project        | JWST EDGE BANDWIDTH MAP
# Output folder  | /content/JWST_OUTPUT
# Requested band | 36.5 to 46.5 Gly
# Objects        | 15
# Color code     | red = higher z / older light, blue = lowe…
# Mode           | Curated metadata only; no FITS/image down…
# RESULTS
# Metric                                   | Value
# -----------------------------------------------------
# Known JWST objects in 36.5-46.5 Gly band | 0
# Most distant object in table             | MoM-z14
# Most distant table distance              | 33.861 Gly
# Gap to 36.5 Gly                          | 2.639 Gly
# 36.5 Gly approx redshift                 | z ≈ 23.165
#
# FRONTIER TABLE
# Rank | Name              | z       | Dist Gly | Age Myr | Status
# ---------------------------------------------------------------------------------
# ...

# %%
# !curl -fsSL -o /content/JWST_0007_Z13_TO_Z50_INVENTORY.py https://raw.githubusercontent.com/gear66me-ui/JWST/main/JWST_0007_Z13_TO_Z50_INVENTORY.py
# %run /content/JWST_0007_Z13_TO_Z50_INVENTORY.py
# Out:
# CODE OUTPUT: JWST_0007
#
# CODE INPUTS
# Field                  | Value
# -------------------------------------------------------------------
# Project                | JWST Z13 TO Z50 GALAXY INVENTORY
# Output folder          | /content/JWST_OUTPUT
# Redshift interval      | 13.0 <= z <= 50.0
# Known/reported entries | 7
# Distance model         | Astropy Planck18 cosmology
# Mode                   | Curated inventory; no FITS/image downloads
# RESULTS
# Metric                      | Value
# ------------------------------------------------------------------------
# Inventory rows in 13<=z<=50 | 7
# Highest z in inventory      | 14.4400
# Lowest z in inventory       | 13.0000
# Non-empty 1-z bins          | 2
# Empty bins above z=15       | 36
# Interpretation              | inventory stops near z=14.44; z=15..50 is…
#
# INVENTORY TABLE
# Rank | Name              | z       | Dist Gly | Age Myr | Confidence
# ...

# %%
# !curl -fsSL -o /content/JWST_0008_EDGE_BAND_LABEL_FIX.py https://raw.githubusercontent.com/gear66me-ui/JWST/main/JWST_0008_EDGE_BAND_LABEL_FIX.py
# %run /content/JWST_0008_EDGE_BAND_LABEL_FIX.py
# Out:
# CODE OUTPUT: JWST_0008
#
# RESULTS
# Most distant object : MoM-z14
# Max distance        : 33.860558 Gly
# Gap to 36.5 Gly     : 2.639442 Gly
# 36.5 Gly redshift   : z ≈ 23.165376
#
# OUTPUT SUMMARY
# PNG full : /content/JWST_OUTPUT/PNG/JWST_0008_FULL_EDGE_BAND_LABEL_FIX.png
# PNG zoom : /content/JWST_OUTPUT/PNG/JWST_0008_ZOOM_CLUSTER_NUMBERED_LABELS.png
# CSV      : /content/JWST_OUTPUT/CSV/JWST_0008_LABEL_FIX_GALAXY_TABLE.csv
#
# COMMENTS
# Labels were moved off the crowded cluster and connected with leader lines.
# The zoom plot uses numbered point markers plus a right-side engineering legend.
# The data and cosmology are unchanged from the edge-band analysis.
#
# 2026-07-09T23:24:02+00:00
# # JWST_0008

# %%
# !curl -fsSL -o /content/JWST_0009_SPLIT_RIGHT_LABELS.py https://raw.githubusercontent.com/gear66me-ui/JWST/main/JWST_0009_SPLIT_RIGHT_LABELS.py
# %run /content/JWST_0009_SPLIT_RIGHT_LABELS.py
# Out:
# CODE OUTPUT: JWST_0009
#
# RESULTS
# Most distant object : MoM-z14
# Max distance        : 33.860558 Gly
# Gap to 36.5 Gly     : 2.639442 Gly
# 36.5 Gly redshift   : z ≈ 23.165376
#
# OUTPUT SUMMARY
# PNG split labels : /content/JWST_OUTPUT/PNG/JWST_0009_SPLIT_RIGHT_LABELS.png
# PNG clean points : /content/JWST_OUTPUT/PNG/JWST_0009_CLEAN_POINTS_ONLY.png
# CSV              : /content/JWST_OUTPUT/CSV/JWST_0009_SPLIT_RIGHT_LABELS_TABLE.csv
#
# COMMENTS
# Labels are now moved into right-side lanes, split above and below the cluster.
# Leader lines connect each object to its label; the data cluster is no longer covered by text.
# Matplotlib only. No AI images.
#
# 2026-07-09T23:27:25+00:00
# # JWST_0009

# %%
# !curl -fsSL -o /content/JWST_0010_Z0_Z15_CURVE_ONLY.py https://raw.githubusercontent.com/gear66me-ui/JWST/main/JWST_0010_Z0_Z15_CURVE_ONLY.py
# %run /content/JWST_0010_Z0_Z15_CURVE_ONLY.py
# Out:
# CODE OUTPUT: JWST_0010
#
# CODE INPUTS
# Field        | Value
# -------------------------------------------------------------
# Project      | JWST Z0 TO Z15 CURVE ONLY
# z range      | 0.0 to 15.0
# Curve points | 3001
# Cosmology    | Astropy Planck18
# Mode         | theoretical curve only; no individual galaxies
#
# RESULTS
# Metric                     | Value
# ------------------------------------------------------------------------
# z=0 distance               | 0.000000 Gly
# z=15 distance              | 34.092872 Gly
# z=15 age                   | 268.289 Myr
# z=14.44 reference distance | 33.860558 Gly
# z=14.44 reference age      | 283.071 Myr
# Interpretation             | smooth curve; slope decreases with redshift
#
# OUTPUT SUMMARY
# Type | Path
# -------------------------------------------------------
# png  | /content/JWST_OUTPUT/PNG/JWST_0010_Z0_Z15_COMOV…
# png  | /content/JWST_OUTPUT/PNG/JWST_0010_Z0_Z15_UNIVE…
# ...

# %%
# !curl -fsSL -o /content/JWST_0012_PHANGS_FILTER_DASHBOARD.py https://raw.githubusercontent.com/gear66me-ui/JWST/main/JWST_0012_PHANGS_FILTER_DASHBOARD.py
# %run /content/JWST_0012_PHANGS_FILTER_DASHBOARD.py
# Out:
# CODE OUTPUT: JWST_0012
#
# CODE INPUTS
# Field                | Value
# ------------------------------------------------------
# Project              | PHANGS-JWST FILTER DASHBOARD
# Galaxy sample        | 19 PHANGS-JWST Cycle 1 galaxies
# Filter set           | 8 filters from 2-21 micron
# Image/FITS downloads | none
# Plot engine          | matplotlib only
#
# RESULTS
# Metric               | Value
# -------------------------------------------
# Nearest galaxy       | NGC 5068 | 5.20 Mpc
# Farthest galaxy      | NGC 1365 | 19.57 Mpc
# Shortest wavelength  | 2.00 micron
# Longest wavelength   | 21.00 micron
# Resolution grid rows | 152
#
# OUTPUT SUMMARY
# Type | Path
# -----------------------------------------------------------------
# png  | /content/JWST_OUTPUT/PNG/JWST_0012_PHANGS_FILTER_LADDER.p…
# png  | /content/JWST_OUTPUT/PNG/JWST_0012_PHANGS_RESOLUTION_CURV…
# png  | /content/JWST_OUTPUT/PNG/JWST_0012_PHANGS_GALAXY_DISTANCE…
# ...
